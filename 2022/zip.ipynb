# %%
import pandas as pd

# %%
pd.read_csv('final_data.csv')
# Out:
#                 Player Pos  Age   Tm   G    GS    MP   FG   FGA    FG%  ...  \
# 0          Aaron James  SF   25  NOJ  80   NaN  26.5  5.4  10.8  0.497  ...
# 1        Fred Saunders  SF   26  NOJ  56   NaN  11.5  1.8   4.2  0.423  ...
# 2         Freddie Boyd  SG   27  NOJ  21   NaN  17.3  2.1   5.2  0.400  ...
# 3        Gail Goodrich  SG   34  NOJ  81   NaN  31.5  6.4  13.0  0.495  ...
# 4           Gus Bailey  SG   26  NOJ  48   NaN   9.4  1.2   2.9  0.424  ...
# ...                ...  ..  ...  ...  ..   ...   ...  ...   ...    ...  ...
# 18802     Micah Potter   C   23  DET   3   0.0  10.3  1.7   3.7  0.455  ...
# 18803  Rodney McGruder  SG   30  DET  51   2.0  14.8  1.9   4.4  0.436  ...
# 18804        Saben Lee  PG   22  DET  37   0.0  16.3  1.9   4.8  0.390  ...
# 18805       Saddiq Bey  SF   22  DET  82  82.0  33.0  5.5  13.9  0.396  ...
# 18806   Trayvon Palmer  SG   27  DET   1   0.0  17.0  0.0   1.0  0.000  ...
#
# ...
